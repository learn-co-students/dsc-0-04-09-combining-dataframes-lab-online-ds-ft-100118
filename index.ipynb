# %% [markdown]
# # Combining DataFrames With Pandas - Lab
#
# ## Introduction
#
# In this lab, we'll gain practice combining DataFrames through concatenation.  We'll also learn to read in tables from a database and store them in separate tables, as well as how to execute various types of joins to selectively combine the information stored in the tables!
#
#
# ## Objectives:
# You will be able to:
# * Understand and explain when to use DataFrame joins and merges
# * Be able to use pd.merge when combining DataFrames based on column values
# * Understand, explain and use a range of DataFrame merge types: outer, inner, left and right
# * Use pd.concat() to stack DataFrames
#
# ## Getting Started
#
# We'll start with a quick section to help us gain practice with concatenating datasets using `pd.concat()`.
#
# ### Concatenating DataFrames
#
# Run the cell below to create some sample DataFrames for us to work with.

# %%
import pandas as pd
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']},
                    index=[0, 1, 2, 3])


df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'],
                    'C': ['C4', 'C5', 'C6', 'C7'],
                    'D': ['D4', 'D5', 'D6', 'D7']},
                    index=[4, 5, 6, 7])

df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                    'B': ['B8', 'B9', 'B10', 'B11'],
                    'C': ['C8', 'C9', 'C10', 'C11'], 
                    'D': ['D8', 'D9', 'D10', 'D11']},
                    index=[8, 9, 10, 11])

# %% [markdown]
# Now that we have multiple DataFrames to work with, we can execute a concatenation to join them together.
#
# In the cell below, concatenate the 3 DataFrames together using the appropriate function.

# %%
combined_df =  [df1, df2, df3]
big_df = pd.concat(combined_df)
big_df.head(12)
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# **_EXPECTED OUTPUT:_**
#
# <img src="er1.png">
#
# ### Setting Join Conditions With Concatenation
#
# We can also specify if the concatenation is an **_Outer Join_** or an **_Inner Join_**.  Next, we'll execute an inner join. Before we do, we need to create another table that contains some overlapping index values with a DataFrame that already exists.
#
# Run the cell below to create the new DataFrame.

# %%
df4 = pd.DataFrame({'B': ['B2', 'B3', 'B6', 'B7'],
                    'D': ['D2', 'D3', 'D6', 'D7'],
                    'F': ['F2', 'F3', 'F6', 'F7']},
                    index=[2, 3, 6, 7])

# %% [markdown]
# Now, in the cell below, use the `pd.concat()` method to join DataFrames 1 and 4.  However, this time, specify that the `join` is `'inner'`, and `axis=1`.

# %%
df1_and_4 =  pd.concat([df1, df4], axis=1, join='inner')
df1_and_4
# Out:
#     A   B   C   D   B   D   F
# 2  A2  B2  C2  D2  B2  D2  F2
# 3  A3  B3  C3  D3  B3  D3  F3

# %% [markdown]
# **_EXPECTED OUTPUT:_**
#
# <img src='er2.png'>
#
# We'll notice that in this case, the results returned contain only the rows with indexes that exist in both tables--rows 2 and 3.  The resulting table contains the values for each column in both tables for the rows.
#
# Note that there are many, many ways that we can make full use of the `concat()` functionality in pandas to join DataFrames together--these are just a few of the most common examples pulled from the pandas documentation on the subject.  For a full view of all the ways we can use `pd.concat()`, see the [pandas documentation](http://pandas.pydata.org/pandas-docs/stable/merging.html)!

# %% [markdown]
# ## Loading In Data From SQL Database Tables
#
# Now, we'll move on to working with the Hearthstone cards database.  This database contains information on cards from the popular game, [Hearthstone](https://playhearthstone.com/en-us/)! For full information on the dataset, see the  [kaggle page](https://www.kaggle.com/jeradrose/hearthstone-cards) for this dataset.
#
# This database consists of the following tables:
#
# * _cards_
# * *dust_costs*
# * _entourages_
# * _mechanics_
# * *play_requirements*
#
# Many of rows in each table--but not all--correspond to the same cards. As such, each table contains a column called `card_id` which acts as a **_Primary Key_** for each table.  We'll make use of these keys to **_join_** the different tables together into a single DataFrame.  We'll also experiment with different types of joins to help us decide exactly what information we want to combine.
#
# Before we can begin working with the database, we'll first need to connect to it.  For this, we'll use the `sqlalchemy` library.
#
# In the cell below:
#
# * Import the `create_engine` module from `sqlalchemy`
# * Create an engine that connects to `sqlite:///database.sqlite`.

# %%
from sqlalchemy import create_engine

database_path = "sqlite:///database.sqlite"

engine = create_engine("sqlite:///database.sqlite", echo=False)

# %% [markdown]
# Now that we've successfully connected to our Database, we'll make use of pandas to read in each table individually.
#
# In the cell below, read in each sql table into separate pandas DataFrames using the `read_sql_table` method.
#
# The first argument should be a string corresponding to the name of the table, and the second argument should be the `engine` object we created in the cell above.
#
# If you're unsure of how to do this, see the [documentation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html).

# %%
cards_df =pd.read_sql_table('cards', con="sqlite:///database.sqlite")
dust_df = pd.read_sql_table('dust_costs', con="sqlite:///database.sqlite")
entourages_df = pd.read_sql_table('entourages', con="sqlite:///database.sqlite")
mechanics_df = pd.read_sql_table('mechanics', con="sqlite:///database.sqlite")
play_requirements_df = pd.read_sql_table('play_requirements', con="sqlite:///database.sqlite")

# %% [markdown]
# Great.  Now, let's set the correct column, `card_id`, as the index column for each of these tables, and then display each to ensure that everything is as expected.
#
# For each of the dataframes we created in the cell above, call the `.set_index()` method and pass in `card_id`.  Also set `inplace=True`.  Then, display the head of each respective DataFrame to ensure everything worked.
#
# **_NOTE:_** Since we are performing this operation in place, running any cell a second time will result in pandas throwing an error.  If you need to run something a second time, restart the kernel using the jupyter notebook menu at the top of the page.

# %%
cards_df.set_index('card_id',inplace=True)
cards_df.head()
# Out:
#            player_class    type                name      set  \
# card_id
# KARA_00_07         MAGE   SPELL       Astral Portal     KARA
# NEW1_008a         DRUID   SPELL   Ancient Teachings  EXPERT1
# BRM_010t2         DRUID  MINION  Druid of the Flame      BRM
# AT_132          NEUTRAL  MINION  Justicar Trueheart      TGT
# OG_141          NEUTRAL  MINION   Faceless Behemoth       OG
#
#                                                          text  cost  attack  \
# card_id
# KARA_00_07           Summon a random <b>Legendary</b> minion.   1.0     NaN
# NEW1_008a                                        Draw a card.   0.0     NaN
# BRM_010t2                                                None   3.0     2.0
# AT_132      <b>Battlecry:</b> Replace your starting Hero P...   6.0     6.0
# OG_141                                                   None  10.0    10.0
#
#             health     rarity  collectible  \
# card_id
# KARA_00_07     NaN       None          NaN
# NEW1_008a      NaN       None          NaN
# BRM_010t2      5.0     COMMON          NaN
# AT_132         3.0  LEGENDARY          1.0
# OG_141        10.0     COMMON          1.0
#
#                                                        flavor   race  \
# card_id
# KARA_00_07                                               None   None
# NEW1_008a                                                None   None
# BRM_010t2                                                None  BEAST
# AT_132      It's like putting racing stripes and a giant s...   None
# OG_141      Rejected names: Forty-Foot Faceless, Big ol' N...   None
#
#            how_to_earn how_to_earn_golden targeting_arrow_text faction  \
# card_id
# KARA_00_07        None               None                 None    None
# NEW1_008a         None               None                 None    None
# BRM_010t2         None               None                 None    None
# AT_132            None               None                 None    None
# OG_141            None               None                 None    None
#
#             durability
# card_id
# KARA_00_07         NaN
# NEW1_008a          NaN
# BRM_010t2          NaN
# AT_132             NaN
# OG_141             NaN

# %%
dust_df.set_index('card_id',inplace=True)
dust_df.head()
# Out:
#                       action  cost
# card_id
# BRM_010t2    CRAFTING_NORMAL    40
# BRM_010t2    CRAFTING_GOLDEN   400
# BRM_010t2  DISENCHANT_NORMAL     5
# BRM_010t2  DISENCHANT_GOLDEN    50
# AT_132       CRAFTING_NORMAL  1600

# %%
entourages_df.set_index('card_id',inplace=True)
entourages_df.head()
# Out:
#            entourage_card_id
# card_id
# KAR_A10_22        KAR_A10_09
# KAR_A10_22        KAR_A10_02
# KAR_A10_22        KAR_A10_08
# KAR_A10_22        KAR_A10_04
# KAR_A10_22        KAR_A10_05

# %%
mechanics_df.set_index('card_id',inplace=True)
mechanics_df.head()
# Out:
#                      mechanic
# card_id
# AT_132              BATTLECRY
# GVG_011a  TAG_ONE_TURN_EFFECT
# EX1_583             BATTLECRY
# LOE_007t            EVIL_GLOW
# LOE_007t   ImmuneToSpellpower

# %%
play_requirements_df .set_index('card_id',inplace=True)
play_requirements_df .head()
# Out:
#                      play_requirement  value
# card_id
# KARA_00_07       REQ_NUM_MINION_SLOTS      1
# PRO_001a         REQ_NUM_MINION_SLOTS      1
# NAX1_01          REQ_NUM_MINION_SLOTS      1
# DS1h_292_H1           REQ_STEADY_SHOT      0
# DS1h_292_H1  REQ_MINION_OR_ENEMY_HERO      0

# %% [markdown]
# ### Executing Joins
#
# Now that we have the tables loaded correctly, we're going to execute some joins. There are 4 different kinds of joins, which can best be visualized with venn diagrams:
#
# <img src='joins.png'>
#
# In these diagrams, each circle represents a DataFrame or SQL Table.  The left table is the table we are working with, and the right table is the table we want to join to the table we are working with.  We'll start by executing the most common type of join, an **_Inner Join_**.
#
# In the cell below, join `cards_df` with `mechanics_df` using the built-in `.join()` method on the `cards_df` object.
#
# Pass in the following parameters:
# * the table we want to join with, `mechanics_df`
# * The `how` parameter set to the type of join we want, `'inner'`

# %%
cards_with_mechanics_df = pd.concat([cards_df, mechanics_df], axis=1, join='inner')
cards_with_mechanics_df
# Out:
#                    player_class         type                   name      set  \
# card_id
# AT_132                  NEUTRAL       MINION     Justicar Trueheart      TGT
# GVG_011a                NEUTRAL  ENCHANTMENT             Shrink Ray      GVG
# EX1_583                 NEUTRAL       MINION     Priestess of Elune  EXPERT1
# LOE_007t                WARLOCK        SPELL                Cursed!      LOE
# LOE_007t                WARLOCK        SPELL                Cursed!      LOE
# CFM_095                 NEUTRAL       MINION        Weasel Tunneler    GANGS
# BRM_018                 PALADIN       MINION         Dragon Consort      BRM
# GVG_030                   DRUID       MINION      Anodized Robo Cub      GVG
# GVG_030                   DRUID       MINION      Anodized Robo Cub      GVG
# CS2_227                 NEUTRAL       MINION  Venture Co. Mercenary  EXPERT1
# KAR_062                 NEUTRAL       MINION  Netherspite Historian     KARA
# CFM_712_t17             NEUTRAL       MINION             Jade Golem    GANGS
# BRM_011t                 SHAMAN  ENCHANTMENT             Lava Shock      BRM
# BRMA10_3H               NEUTRAL   HERO_POWER            The Rookery      BRM
# KAR_710m                NEUTRAL       MINION        Animated Shield     KARA
# EX1_295o                   MAGE  ENCHANTMENT              Ice Block  EXPERT1
# OG_158                  NEUTRAL       MINION       Zealous Initiate       OG
# LOE_110t                NEUTRAL        SPELL          Ancient Curse      LOE
# LOE_110t                NEUTRAL        SPELL          Ancient Curse      LOE
# BRMA13_4H               NEUTRAL   HERO_POWER             Wild Magic      BRM
# EX1_145o                  ROGUE  ENCHANTMENT            Preparation  EXPERT1
# LOEA09_2e               NEUTRAL  ENCHANTMENT                Enraged      LOE
# EX1_570e                NEUTRAL  ENCHANTMENT                   Bite  EXPERT1
# GVG_069                 NEUTRAL       MINION        Antique Healbot      GVG
# hexfrog                 NEUTRAL       MINION                   Frog     CORE
# OG_145                  NEUTRAL       MINION           Psych-o-Tron       OG
# OG_145                  NEUTRAL       MINION           Psych-o-Tron       OG
# AT_090                  NEUTRAL       MINION       Mukla's Champion      TGT
# AT_060                   HUNTER        SPELL              Bear Trap      TGT
# TB_MechWar_Minion1      NEUTRAL       MINION               Mech Fan       TB
# ...                         ...          ...                    ...      ...
# EX1_284                 NEUTRAL       MINION            Azure Drake  EXPERT1
# LOE_038                 NEUTRAL       MINION         Naga Sea Witch      LOE
# AT_083                  NEUTRAL       MINION       Dragonhawk Rider      TGT
# TB_CoOpv3_BOSS2e        NEUTRAL  ENCHANTMENT      Getting Angry....       TB
# GVG_009                  PRIEST       MINION           Shadowbomber      GVG
# CFM_338                  HUNTER       MINION       Trogg Beastrager    GANGS
# GVG_097                 NEUTRAL       MINION          Lil' Exorcist      GVG
# GVG_097                 NEUTRAL       MINION          Lil' Exorcist      GVG
# CFM_852                 NEUTRAL       MINION           Lotus Agents    GANGS
# LOE_020                  HUNTER       MINION           Desert Camel      LOE
# CFM_781                   ROGUE       MINION   Shaku, the Collector    GANGS
# GVG_090                 NEUTRAL       MINION          Madder Bomber      GVG
# GVG_120                 NEUTRAL       MINION       Hemet Nesingwary      GVG
# EX1_055o                NEUTRAL  ENCHANTMENT              Empowered  EXPERT1
# CFM_321                 NEUTRAL       MINION  Grimestreet Informant    GANGS
# EX1_082                 NEUTRAL       MINION             Mad Bomber  EXPERT1
# FP1_017                 NEUTRAL       MINION       Nerub'ar Weblord     NAXX
# FP1_001                 NEUTRAL       MINION            Zombie Chow     NAXX
# AT_089                  NEUTRAL       MINION   Boneguard Lieutenant      TGT
# CFM_646                 NEUTRAL       MINION       Backstreet Leper    GANGS
# AT_084                  NEUTRAL       MINION          Lance Carrier      TGT
# OG_044a                   DRUID       MINION      Druid of the Claw  EXPERT1
# OG_044a                   DRUID       MINION      Druid of the Claw  EXPERT1
# LOEA09_3d               NEUTRAL   HERO_POWER         Getting Hungry      LOE
# BRMA13_4                NEUTRAL   HERO_POWER             Wild Magic      BRM
# EX1_009                 NEUTRAL       MINION          Angry Chicken  EXPERT1
# BRMA10_3                NEUTRAL   HERO_POWER            The Rookery      BRM
# NAX3_02H                NEUTRAL   HERO_POWER               Web Wrap     NAXX
# AT_083e                 NEUTRAL  ENCHANTMENT          Dragonhawkery      TGT
# CS2_031                    MAGE        SPELL              Ice Lance  EXPERT1
#
#                                                                  text  cost  \
# card_id
# AT_132              <b>Battlecry:</b> Replace your starting Hero P...   6.0
# GVG_011a                                         -2 Attack this turn.   NaN
# EX1_583              <b>Battlecry:</b> Restore 4 Health to your hero.   6.0
# LOE_007t            While this is in your hand, take 2 damage at t...   2.0
# LOE_007t            While this is in your hand, take 2 damage at t...   2.0
# CFM_095             <b>Deathrattle:</b> Shuffle this minion into y...   1.0
# BRM_018             <b>Battlecry:</b> The next Dragon you play cos...   5.0
# GVG_030             <b>Taunt</b>. <b>Choose One -</b>\n+1 Attack; ...   2.0
# GVG_030             <b>Taunt</b>. <b>Choose One -</b>\n+1 Attack; ...   2.0
# CS2_227                                   Your minions cost (3) more.   5.0
# KAR_062             <b>Battlecry:</b> If you're holding a Dragon, ...   2.0
# CFM_712_t17                                                      None  10.0
# BRM_011t            Cards you play this turn don't cause <b>Overlo...   NaN
# BRMA10_3H           <b>Hero Power</b>\nGive all Corrupted Eggs +1 ...   0.0
# KAR_710m                                                 <b>Taunt</b>   2.0
# EX1_295o                        Your hero is <b>Immune</b> this turn.   NaN
# OG_158              <b>Deathrattle:</b> Give a random friendly min...   1.0
# LOE_110t            When you draw this, take 7 damage and draw a c...   0.0
# LOE_110t            When you draw this, take 7 damage and draw a c...   0.0
# BRMA13_4H           <b>Hero Power</b>\nPut a random spell from you...   1.0
# EX1_145o            The next spell you cast this turn costs (3) less.   NaN
# LOEA09_2e                                                   +2 Attack   NaN
# EX1_570e                                         +4 Attack this turn.   NaN
# GVG_069              <b>Battlecry:</b> Restore 8 Health to your hero.   5.0
# hexfrog                                                  <b>Taunt</b>   0.0
# OG_145                             <b>Taunt</b>\n<b>Divine Shield</b>   5.0
# OG_145                             <b>Taunt</b>\n<b>Divine Shield</b>   5.0
# AT_090                 <b>Inspire:</b> Give your other minions +1/+1.   5.0
# AT_060              <b>Secret:</b> After your hero is attacked, su...   2.0
# TB_MechWar_Minion1                                       <b>Taunt</b>   2.0
# ...                                                               ...   ...
# EX1_284             <b>Spell Damage +1</b>. <b>Battlecry:</b> Draw...   5.0
# LOE_038                                          Your cards cost (5).   5.0
# AT_083               <b>Inspire:</b> Gain <b>Windfury</b>\nthis turn.   3.0
# TB_CoOpv3_BOSS2e                                     Now he's mad....   NaN
# GVG_009                 <b>Battlecry:</b> Deal 3 damage to each hero.   1.0
# CFM_338             <b>Battlecry:</b> Give a random Beast in your ...   2.0
# GVG_097             <b>Taunt</b>\n<b>Battlecry:</b> Gain +1/+1 for...   3.0
# GVG_097             <b>Taunt</b>\n<b>Battlecry:</b> Gain +1/+1 for...   3.0
# CFM_852             <b>Battlecry:</b> <b>Discover</b> a Druid, Rog...   5.0
# LOE_020             <b>Battlecry:</b> Put a 1-Cost minion from eac...   3.0
# CFM_781             [x]<b>Stealth</b>. Whenever this\nattacks, add...   3.0
# GVG_090             <b>Battlecry:</b> Deal 6 damage randomly split...   5.0
# GVG_120                            <b>Battlecry:</b> Destroy a Beast.   5.0
# EX1_055o                            Mana Addict has increased Attack.   NaN
# CFM_321             [x]<b>Battlecry:</b> <b>Discover</b> a\nHunter...   2.0
# EX1_082             <b>Battlecry:</b> Deal 3 damage randomly split...   2.0
# FP1_017                  Minions with <b>Battlecry</b> cost (2) more.   2.0
# FP1_001             <b>Deathrattle:</b> Restore 5 Health to the en...   1.0
# AT_089                                <b>Inspire:</b> Gain +1 Health.   2.0
# CFM_646             [x]<b>Deathrattle:</b> Deal 2 damage\nto the e...   3.0
# AT_084              <b>Battlecry:</b> Give a friendly minion +2 At...   2.0
# OG_044a                                   <b>Charge</b>\n<b>Taunt</b>   5.0
# OG_044a                                   <b>Charge</b>\n<b>Taunt</b>   5.0
# LOEA09_3d                <b>Hero Power</b>\nSummon a 5/1 Hungry Naga.   0.0
# BRMA13_4            <b>Hero Power</b>\nPut a random spell from you...   1.0
# EX1_009                                     <b>Enrage:</b> +5 Attack.   1.0
# BRMA10_3            <b>Hero Power</b>\nGive all Corrupted Eggs +1 ...   1.0
# NAX3_02H            <b>Hero Power</b>\nReturn 2 random enemy minio...   0.0
# AT_083e                                    <b>Windfury</b> this turn.   NaN
# CS2_031             <b>Freeze</b> a character. If it was already <...   1.0
#
#                     attack  health     rarity  collectible  \
# card_id
# AT_132                 6.0     3.0  LEGENDARY          1.0
# GVG_011a               NaN     NaN       None          NaN
# EX1_583                5.0     4.0     COMMON          1.0
# LOE_007t               NaN     NaN       None          NaN
# LOE_007t               NaN     NaN       None          NaN
# CFM_095                1.0     1.0       EPIC          1.0
# BRM_018                5.0     5.0       RARE          1.0
# GVG_030                2.0     2.0     COMMON          1.0
# GVG_030                2.0     2.0     COMMON          1.0
# CS2_227                7.0     6.0     COMMON          1.0
# KAR_062                1.0     3.0     COMMON          1.0
# CFM_712_t17           17.0    17.0       None          NaN
# BRM_011t               NaN     NaN       None          NaN
# BRMA10_3H              NaN     NaN       None          NaN
# KAR_710m               0.0     5.0       None          NaN
# EX1_295o               NaN     NaN       None          NaN
# OG_158                 1.0     1.0     COMMON          1.0
# LOE_110t               NaN     NaN       None          NaN
# LOE_110t               NaN     NaN       None          NaN
# BRMA13_4H              NaN     NaN       None          NaN
# EX1_145o               NaN     NaN       None          NaN
# LOEA09_2e              NaN     NaN       None          NaN
# EX1_570e               NaN     NaN       None          NaN
# GVG_069                3.0     3.0     COMMON          1.0
# hexfrog                0.0     1.0     COMMON          NaN
# OG_145                 3.0     4.0     COMMON          1.0
# OG_145                 3.0     4.0     COMMON          1.0
# AT_090                 4.0     3.0     COMMON          1.0
# AT_060                 NaN     NaN     COMMON          1.0
# TB_MechWar_Minion1     1.0     1.0       None          NaN
# ...                    ...     ...        ...          ...
# EX1_284                4.0     4.0       RARE          1.0
# LOE_038                5.0     5.0       EPIC          1.0
# AT_083                 3.0     3.0     COMMON          1.0
# TB_CoOpv3_BOSS2e       NaN     NaN       None          NaN
# GVG_009                2.0     1.0       EPIC          1.0
# CFM_338                3.0     2.0       RARE          1.0
# GVG_097                2.0     3.0       RARE          1.0
# GVG_097                2.0     3.0       RARE          1.0
# CFM_852                5.0     3.0       RARE          1.0
# LOE_020                2.0     4.0     COMMON          1.0
# CFM_781                2.0     3.0  LEGENDARY          1.0
# GVG_090                5.0     4.0       RARE          1.0
# GVG_120                6.0     3.0  LEGENDARY          1.0
# EX1_055o               NaN     NaN       None          NaN
# CFM_321                1.0     1.0       RARE          1.0
# EX1_082                3.0     2.0     COMMON          1.0
# FP1_017                1.0     4.0     COMMON          1.0
# FP1_001                2.0     3.0     COMMON          1.0
# AT_089                 3.0     2.0     COMMON          1.0
# CFM_646                3.0     1.0     COMMON          1.0
# AT_084                 1.0     2.0     COMMON          1.0
# OG_044a                4.0     6.0     COMMON          NaN
# OG_044a                4.0     6.0     COMMON          NaN
# LOEA09_3d              NaN     NaN       None          NaN
# BRMA13_4               NaN     NaN       None          NaN
# EX1_009                1.0     1.0       RARE          1.0
# BRMA10_3               NaN     NaN       None          NaN
# NAX3_02H               NaN     NaN       None          NaN
# AT_083e                NaN     NaN       None          NaN
# CS2_031                NaN     NaN     COMMON          1.0
#
#                                                                flavor  \
# card_id
# AT_132              It's like putting racing stripes and a giant s...
# GVG_011a                                                         None
# EX1_583             If she threatens to "moon" you, it's not what ...
# LOE_007t                                                         None
# LOE_007t                                                         None
# CFM_095             He's the reason the First Bank of Gadgetzan ha...
# BRM_018             Everybody wants someone to snuggle with. Even ...
# GVG_030             It's adorable! AND OH MY GOODNESS WHY IS IT EA...
# GVG_030             It's adorable! AND OH MY GOODNESS WHY IS IT EA...
# CS2_227                        No Job is too big.  No fee is too big.
# KAR_062             She can tell you all about the history of peop...
# CFM_712_t17                                                      None
# BRM_011t                                                         None
# BRMA10_3H                                                        None
# KAR_710m                                                         None
# EX1_295o                                                         None
# OG_158              Ok, Initiate. You need to settle down and do y...
# LOE_110t                                                         None
# LOE_110t                                                         None
# BRMA13_4H                                                        None
# EX1_145o                                                         None
# LOEA09_2e                                                        None
# EX1_570e                                                         None
# GVG_069             They don't make 'em like they used to! (Becaus...
# hexfrog                                                          None
# OG_145              "Annoyinger-o-Tron" was just too unwieldy. And...
# OG_145              "Annoyinger-o-Tron" was just too unwieldy. And...
# AT_090                  An elegant gorilla, for a more civilized age.
# AT_060              You'll never guess what's in that conveniently...
# TB_MechWar_Minion1                                               None
# ...                                                               ...
# EX1_284             They initially planned to be the Beryl or Ceru...
# LOE_038             If she had studied harder, she would have been...
# AT_083              Check it out.  You can do barrel rolls on this...
# TB_CoOpv3_BOSS2e                                                 None
# GVG_009             Shadowbomber does her job, but she's kind of p...
# CFM_338             Still angry that the Gadgetzan Rager Club woul...
# GVG_097             Warlocks have the town exorcist on speed dial ...
# GVG_097             Warlocks have the town exorcist on speed dial ...
# CFM_852                      Mostly, they stand around and look cool.
# LOE_020             Dang.  This card is sweet.  Almost as sweet as...
# CFM_781             Aya even staged an intervention once, but Shak...
# GVG_090                                      Dang, Bomber, calm down.
# GVG_120             It's hard to make a living as a hunter in a wo...
# EX1_055o                                                         None
# CFM_321             "Naw, naw.  You're talkin' about Grime BOULEVA...
# EX1_082             He's not really all that crazy, he is just not...
# FP1_017             Weblords spend all day making giant trampoline...
# FP1_001                              Zombie.  It's what's for dinner.
# AT_089              Underneath all that impressive armor, he's jus...
# CFM_646             Quit playing games with his heart. And his fin...
# AT_084              Lance Carrier is an obscure entry level positi...
# OG_044a                                                          None
# OG_044a                                                          None
# LOEA09_3d                                                        None
# BRMA13_4                                                         None
# EX1_009             There is no beast more frightening (or ridicul...
# BRMA10_3                                                         None
# NAX3_02H                                                         None
# AT_083e                                                          None
# CS2_031             The trick is not to break the lance.  Otherwis...
#
#                           race  \
# card_id
# AT_132                    None
# GVG_011a                  None
# EX1_583                   None
# LOE_007t                  None
# LOE_007t                  None
# CFM_095                  BEAST
# BRM_018                 DRAGON
# GVG_030             MECHANICAL
# GVG_030             MECHANICAL
# CS2_227                   None
# KAR_062                   None
# CFM_712_t17               None
# BRM_011t                  None
# BRMA10_3H                 None
# KAR_710m                  None
# EX1_295o                  None
# OG_158                    None
# LOE_110t                  None
# LOE_110t                  None
# BRMA13_4H                 None
# EX1_145o                  None
# LOEA09_2e                 None
# EX1_570e                  None
# GVG_069             MECHANICAL
# hexfrog                  BEAST
# OG_145              MECHANICAL
# OG_145              MECHANICAL
# AT_090                   BEAST
# AT_060                    None
# TB_MechWar_Minion1        None
# ...                        ...
# EX1_284                 DRAGON
# LOE_038                   None
# AT_083                    None
# TB_CoOpv3_BOSS2e          None
# GVG_009                   None
# CFM_338                   None
# GVG_097                   None
# GVG_097                   None
# CFM_852                   None
# LOE_020                  BEAST
# CFM_781                   None
# GVG_090                   None
# GVG_120                   None
# EX1_055o                  None
# CFM_321                   None
# EX1_082                   None
# FP1_017                   None
# FP1_001                   None
# AT_089                    None
# CFM_646                   None
# AT_084                    None
# OG_044a                  BEAST
# OG_044a                  BEAST
# LOEA09_3d                 None
# BRMA13_4                  None
# EX1_009                  BEAST
# BRMA10_3                  None
# NAX3_02H                  None
# AT_083e                   None
# CS2_031                   None
#
#                                                           how_to_earn  \
# card_id
# AT_132                                                           None
# GVG_011a                                                         None
# EX1_583                                                          None
# LOE_007t                                                         None
# LOE_007t                                                         None
# CFM_095                                                          None
# BRM_018             Unlocked in Blackrock Spire, in the Blackrock ...
# GVG_030                                                          None
# GVG_030                                                          None
# CS2_227                                                          None
# KAR_062              Unlocked in the Spire, in One Night in Karazhan.
# CFM_712_t17                                                      None
# BRM_011t                                                         None
# BRMA10_3H                                                        None
# KAR_710m                                                         None
# EX1_295o                                                         None
# OG_158                                                           None
# LOE_110t                                                         None
# LOE_110t                                                         None
# BRMA13_4H                                                        None
# EX1_145o                                                         None
# LOEA09_2e                                                        None
# EX1_570e                                                         None
# GVG_069                                                          None
# hexfrog                                                          None
# OG_145                                                           None
# OG_145                                                           None
# AT_090                                                           None
# AT_060                                                           None
# TB_MechWar_Minion1                                               None
# ...                                                               ...
# EX1_284                                                          None
# LOE_038             Unlocked in The Ruined City, in the League of ...
# AT_083                                                           None
# TB_CoOpv3_BOSS2e                                                 None
# GVG_009                                                          None
# CFM_338                                                          None
# GVG_097                                                          None
# GVG_097                                                          None
# CFM_852                                                          None
# LOE_020             Unlocked in the Hall of Explorers, in the Leag...
# CFM_781                                                          None
# GVG_090                                                          None
# GVG_120                                                          None
# EX1_055o                                                         None
# CFM_321                                                          None
# EX1_082                                                          None
# FP1_017             Unlocked in The Arachnid Quarter, in the Naxxr...
# FP1_001             Unlocked in The Construct Quarter, in the Naxx...
# AT_089                                                           None
# CFM_646                                                          None
# AT_084                                                           None
# OG_044a                                                          None
# OG_044a                                                          None
# LOEA09_3d                                                        None
# BRMA13_4                                                         None
# EX1_009                                                          None
# BRMA10_3                                                         None
# NAX3_02H                                                         None
# AT_083e                                                          None
# CS2_031                                                          None
#
#                                                    how_to_earn_golden  \
# card_id
# AT_132                                                           None
# GVG_011a                                                         None
# EX1_583                                                          None
# LOE_007t                                                         None
# LOE_007t                                                         None
# CFM_095                                                          None
# BRM_018             Crafting unlocked in Blackrock Spire, in the B...
# GVG_030                                                          None
# GVG_030                                                          None
# CS2_227                                                          None
# KAR_062             Crafting unlocked in the Spire, in One Night i...
# CFM_712_t17                                                      None
# BRM_011t                                                         None
# BRMA10_3H                                                        None
# KAR_710m                                                         None
# EX1_295o                                                         None
# OG_158                                                           None
# LOE_110t                                                         None
# LOE_110t                                                         None
# BRMA13_4H                                                        None
# EX1_145o                                                         None
# LOEA09_2e                                                        None
# EX1_570e                                                         None
# GVG_069                                                          None
# hexfrog                                                          None
# OG_145                                                           None
# OG_145                                                           None
# AT_090                                                           None
# AT_060                                                           None
# TB_MechWar_Minion1                                               None
# ...                                                               ...
# EX1_284                                                          None
# LOE_038             Crafting unlocked in The Ruined City, in the L...
# AT_083                                                           None
# TB_CoOpv3_BOSS2e                                                 None
# GVG_009                                                          None
# CFM_338                                                          None
# GVG_097                                                          None
# GVG_097                                                          None
# CFM_852                                                          None
# LOE_020             Crafting unlocked in the Hall of Explorers, in...
# CFM_781                                                          None
# GVG_090                                                          None
# GVG_120                                                          None
# EX1_055o                                                         None
# CFM_321                                                          None
# EX1_082                                                          None
# FP1_017             Crafting unlocked in The Arachnid Quarter, in ...
# FP1_001             Crafting unlocked in The Construct Quarter, in...
# AT_089                                                           None
# CFM_646                                                          None
# AT_084                                                           None
# OG_044a                                                          None
# OG_044a                                                          None
# LOEA09_3d                                                        None
# BRMA13_4                                                         None
# EX1_009                                                          None
# BRMA10_3                                                         None
# NAX3_02H                                                         None
# AT_083e                                                          None
# CS2_031                                                          None
#
#                    targeting_arrow_text   faction  durability  \
# card_id
# AT_132                             None      None         NaN
# GVG_011a                           None      None         NaN
# EX1_583                            None      None         NaN
# LOE_007t                           None      None         NaN
# LOE_007t                           None      None         NaN
# CFM_095                            None      None         NaN
# BRM_018                            None      None         NaN
# GVG_030                            None      None         NaN
# GVG_030                            None      None         NaN
# CS2_227                            None     HORDE         NaN
# KAR_062                            None      None         NaN
# CFM_712_t17                        None      None         NaN
# BRM_011t                           None      None         NaN
# BRMA10_3H                          None      None         NaN
# KAR_710m                           None      None         NaN
# EX1_295o                           None      None         NaN
# OG_158                             None      None         NaN
# LOE_110t                           None      None         NaN
# LOE_110t                           None      None         NaN
# BRMA13_4H                          None      None         NaN
# EX1_145o                           None      None         NaN
# LOEA09_2e                          None      None         NaN
# EX1_570e                           None      None         NaN
# GVG_069                            None      None         NaN
# hexfrog                            None      None         NaN
# OG_145                             None      None         NaN
# OG_145                             None      None         NaN
# AT_090                             None      None         NaN
# AT_060                             None      None         NaN
# TB_MechWar_Minion1                 None      None         NaN
# ...                                 ...       ...         ...
# EX1_284                            None      None         NaN
# LOE_038                            None      None         NaN
# AT_083                             None      None         NaN
# TB_CoOpv3_BOSS2e                   None      None         NaN
# GVG_009                            None      None         NaN
# CFM_338                            None      None         NaN
# GVG_097                            None      None         NaN
# GVG_097                            None      None         NaN
# CFM_852                            None      None         NaN
# LOE_020                            None      None         NaN
# CFM_781                            None      None         NaN
# GVG_090                            None      None         NaN
# GVG_120                Destroy a Beast.      None         NaN
# EX1_055o                           None      None         NaN
# CFM_321                            None      None         NaN
# EX1_082                            None  ALLIANCE         NaN
# FP1_017                            None      None         NaN
# FP1_001                            None      None         NaN
# AT_089                             None      None         NaN
# CFM_646                            None      None         NaN
# AT_084                  Give +2 Attack.      None         NaN
# OG_044a                            None      None         NaN
# OG_044a                            None      None         NaN
# LOEA09_3d                          None      None         NaN
# BRMA13_4                           None      None         NaN
# EX1_009                            None      None         NaN
# BRMA10_3                           None      None         NaN
# NAX3_02H                           None      None         NaN
# AT_083e                            None      None         NaN
# CS2_031                            None      None         NaN
#
#                                mechanic
# card_id
# AT_132                        BATTLECRY
# GVG_011a            TAG_ONE_TURN_EFFECT
# EX1_583                       BATTLECRY
# LOE_007t                      EVIL_GLOW
# LOE_007t             ImmuneToSpellpower
# CFM_095                     DEATHRATTLE
# BRM_018                       BATTLECRY
# GVG_030                      CHOOSE_ONE
# GVG_030                           TAUNT
# CS2_227                            AURA
# KAR_062                       BATTLECRY
# CFM_712_t17                  JADE_GOLEM
# BRM_011t            TAG_ONE_TURN_EFFECT
# BRMA10_3H                  AI_MUST_PLAY
# KAR_710m                          TAUNT
# EX1_295o            TAG_ONE_TURN_EFFECT
# OG_158                      DEATHRATTLE
# LOE_110t                        TOPDECK
# LOE_110t             ImmuneToSpellpower
# BRMA13_4H                  AI_MUST_PLAY
# EX1_145o            TAG_ONE_TURN_EFFECT
# LOEA09_2e           TAG_ONE_TURN_EFFECT
# EX1_570e            TAG_ONE_TURN_EFFECT
# GVG_069                       BATTLECRY
# hexfrog                           TAUNT
# OG_145                    DIVINE_SHIELD
# OG_145                            TAUNT
# AT_090                          INSPIRE
# AT_060                           SECRET
# TB_MechWar_Minion1                TAUNT
# ...                                 ...
# EX1_284                       BATTLECRY
# LOE_038                            AURA
# AT_083                          INSPIRE
# TB_CoOpv3_BOSS2e                ENRAGED
# GVG_009                       BATTLECRY
# CFM_338                       BATTLECRY
# GVG_097                       BATTLECRY
# GVG_097                           TAUNT
# CFM_852                       BATTLECRY
# LOE_020                       BATTLECRY
# CFM_781                         STEALTH
# GVG_090                       BATTLECRY
# GVG_120                       BATTLECRY
# EX1_055o            TAG_ONE_TURN_EFFECT
# CFM_321                       BATTLECRY
# EX1_082                       BATTLECRY
# FP1_017                            AURA
# FP1_001                     DEATHRATTLE
# AT_089                          INSPIRE
# CFM_646                     DEATHRATTLE
# AT_084                        BATTLECRY
# OG_044a                          CHARGE
# OG_044a                           TAUNT
# LOEA09_3d                  AI_MUST_PLAY
# BRMA13_4                   AI_MUST_PLAY
# EX1_009                         ENRAGED
# BRMA10_3                   AI_MUST_PLAY
# NAX3_02H                   AI_MUST_PLAY
# AT_083e             TAG_ONE_TURN_EFFECT
# CS2_031                          FREEZE
#
# [1079 rows x 18 columns]

# %% [markdown]
# Examine the output from the cell above and compare it to the original output of both the `cards_df` and `mechanics_df` DataFrame heads we displayed earlier.  Notice how it this now combines the columns from both?
#
# **_Question_**
#
# If you inspect the original `cards_df` DataFrame, you'll notice that it contains  2,819 records.  The result of our inner join, `cards_with_mechanics_df`, conntains only 1079 rows.  Why?
#
# Write your answer below this line:
# Not every card has a mechanic, and therefore the inner join only counts the cards with mechanics________________________________________________________________________________
#
#
# ### Other Types of Joins
#
# By default, the `.join()` method performs a left join if no parameter is passed in for `how=`.  In the cell below, perform a **_Left Join_** of `cards_with_mechanics_df` and `play_requirements_df`, with `cards_with_mechanics_df` as the left table.
#
# Then, display `left_join_df` to inspect our results.

# %%
left_join_df = cards_with_mechanics_df.join(play_requirements_df)
left_join_df
# Out:
#                      player_class         type                        name  \
# card_id
# AT_002                       MAGE        SPELL                      Effigy
# AT_005t                   NEUTRAL       MINION                        Boar
# AT_006                       MAGE       MINION            Dalaran Aspirant
# AT_007                       MAGE       MINION                Spellslinger
# AT_009                       MAGE       MINION                      Rhonin
# AT_010                     HUNTER       MINION                Ram Wrangler
# AT_011e                   NEUTRAL  ENCHANTMENT            Light's Blessing
# AT_012                     PRIEST       MINION            Spawn of Shadows
# AT_017                    NEUTRAL       MINION           Twilight Guardian
# AT_018                     PRIEST       MINION         Confessor Paletress
# AT_019                    WARLOCK       MINION                  Dreadsteed
# AT_022                    WARLOCK        SPELL            Fist of Jaraxxus
# AT_023                    WARLOCK       MINION                Void Crusher
# AT_028                      ROGUE       MINION             Shado-Pan Rider
# AT_030                      ROGUE       MINION           Undercity Valiant
# AT_032                      ROGUE       MINION                Shady Dealer
# AT_035t                     ROGUE        SPELL                     Ambush!
# AT_036                      ROGUE       MINION                   Anub'arak
# AT_037                      DRUID        SPELL                Living Roots
# AT_038                      DRUID       MINION          Darnassus Aspirant
# AT_038                      DRUID       MINION          Darnassus Aspirant
# AT_039                      DRUID       MINION            Savage Combatant
# AT_039e                     DRUID  ENCHANTMENT                      Savage
# AT_040                      DRUID       MINION                  Wildwalker
# AT_040                      DRUID       MINION                  Wildwalker
# AT_040                      DRUID       MINION                  Wildwalker
# AT_040                      DRUID       MINION                  Wildwalker
# AT_042                      DRUID       MINION          Druid of the Saber
# AT_042t                     DRUID       MINION             Sabertooth Lion
# AT_042t2                    DRUID       MINION          Sabertooth Panther
# ...                           ...          ...                         ...
# TB_SPT_DPromoSecret3      WARRIOR        SPELL            Visions of Valor
# TB_SPT_DPromoSecret4      WARRIOR        SPELL             Visions of Fate
# TB_SPT_DPromoSecret5      WARRIOR        SPELL       Visions of the Amazon
# TB_SPT_DPromoSecret6      WARRIOR        SPELL     Visions of the Sorcerer
# TB_SPT_DPromoSecret7      WARRIOR        SPELL  Visions of the Necromancer
# TB_SPT_DPromoSecret9      WARRIOR        SPELL        Visions of Knowledge
# TB_SPT_DPromo_Hero2       WARRIOR         HERO                The Cow King
# TB_SPT_DpromoPortal       NEUTRAL       MINION            Enigmatic Portal
# TB_SPT_DpromoPortal       NEUTRAL       MINION            Enigmatic Portal
# TB_SPT_Minion1            NEUTRAL       MINION                  Shieldsman
# TB_SPT_Minion2            NEUTRAL       MINION             Battle Standard
# TB_SPT_Minion2            NEUTRAL       MINION             Battle Standard
# TU4c_003                  NEUTRAL       MINION                      Barrel
# TU4c_008e                 NEUTRAL  ENCHANTMENT              Might of Mukla
# TU4f_007                  NEUTRAL       MINION                Crazy Monkey
# XXX_001                   NEUTRAL        SPELL                    Damage 1
# XXX_002                   NEUTRAL        SPELL                    Damage 5
# XXX_008                   NEUTRAL        SPELL                      Freeze
# XXX_020                   NEUTRAL        SPELL            Damage all but 1
# XXX_060                   NEUTRAL        SPELL                  Damage All
# XXX_100                   NEUTRAL       MINION    Yogg-Saron Test (Manual)
# XXX_101                   NEUTRAL        SPELL          Set health to full
# XXX_102                   NEUTRAL        SPELL            Add 1 to Health.
# XXX_103                   NEUTRAL        SPELL             Add 2 to Health
# XXX_104                   NEUTRAL        SPELL            Add 4 to Health.
# XXX_105                   NEUTRAL        SPELL            Add 8 to Health.
# XXX_107                   NEUTRAL        SPELL             Set Health to 1
# XXX_110                   NEUTRAL       MINION      Yogg-Saron Test (Auto)
# hexfrog                   NEUTRAL       MINION                        Frog
# tt_010                       MAGE        SPELL                 Spellbender
#
#                            set  \
# card_id
# AT_002                     TGT
# AT_005t                    TGT
# AT_006                     TGT
# AT_007                     TGT
# AT_009                     TGT
# AT_010                     TGT
# AT_011e                    TGT
# AT_012                     TGT
# AT_017                     TGT
# AT_018                     TGT
# AT_019                     TGT
# AT_022                     TGT
# AT_023                     TGT
# AT_028                     TGT
# AT_030                     TGT
# AT_032                     TGT
# AT_035t                    TGT
# AT_036                     TGT
# AT_037                     TGT
# AT_038                     TGT
# AT_038                     TGT
# AT_039                     TGT
# AT_039e                    TGT
# AT_040                     TGT
# AT_040                     TGT
# AT_040                     TGT
# AT_040                     TGT
# AT_042                     TGT
# AT_042t                    TGT
# AT_042t2                   TGT
# ...                        ...
# TB_SPT_DPromoSecret3        TB
# TB_SPT_DPromoSecret4        TB
# TB_SPT_DPromoSecret5        TB
# TB_SPT_DPromoSecret6        TB
# TB_SPT_DPromoSecret7        TB
# TB_SPT_DPromoSecret9        TB
# TB_SPT_DPromo_Hero2         TB
# TB_SPT_DpromoPortal         TB
# TB_SPT_DpromoPortal         TB
# TB_SPT_Minion1              TB
# TB_SPT_Minion2              TB
# TB_SPT_Minion2              TB
# TU4c_003              MISSIONS
# TU4c_008e             MISSIONS
# TU4f_007              MISSIONS
# XXX_001                  CHEAT
# XXX_002                  CHEAT
# XXX_008                  CHEAT
# XXX_020                  CHEAT
# XXX_060                  CHEAT
# XXX_100                  CHEAT
# XXX_101                  CHEAT
# XXX_102                  CHEAT
# XXX_103                  CHEAT
# XXX_104                  CHEAT
# XXX_105                  CHEAT
# XXX_107                  CHEAT
# XXX_110                  CHEAT
# hexfrog                   CORE
# tt_010                 EXPERT1
#
#                                                                    text  cost  \
# card_id
# AT_002                <b>Secret:</b> When a friendly minion dies, su...   3.0
# AT_005t                                                   <b>Charge</b>   3.0
# AT_006                     <b>Inspire:</b> Gain <b>Spell Damage +1</b>.   4.0
# AT_007                <b>Battlecry:</b> Add a random spell to each p...   3.0
# AT_009                <b>Deathrattle:</b> Add 3 copies of Arcane Mis...   8.0
# AT_010                <b>Battlecry:</b> If you have a Beast, summon ...   5.0
# AT_011e                                               Increased Attack.   NaN
# AT_012                      <b>Inspire:</b> Deal 4 damage to each hero.   4.0
# AT_017                <b>Battlecry:</b> If you're holding a Dragon, ...   4.0
# AT_018                <b>Inspire:</b> Summon a random <b>Legendary</...   7.0
# AT_019                         <b>Deathrattle:</b> Summon a Dreadsteed.   4.0
# AT_022                When you play or discard this, deal $4 damage ...   4.0
# AT_023                <b>Inspire:</b> Destroy a random minion for ea...   6.0
# AT_028                                    <b>Combo:</b> Gain +3 Attack.   5.0
# AT_030                                     <b>Combo:</b> Deal 1 damage.   2.0
# AT_032                <b>Battlecry:</b> If you have a Pirate, gain +...   3.0
# AT_035t               When you draw this, summon a 4/4 Nerubian for ...   0.0
# AT_036                <b>Deathrattle:</b> Return this to your hand a...   9.0
# AT_037                <b>Choose One -</b> Deal $2 damage; or Summon ...   1.0
# AT_038                <b>Battlecry:</b> Gain an empty Mana Crystal.\...   2.0
# AT_038                <b>Battlecry:</b> Gain an empty Mana Crystal.\...   2.0
# AT_039                <b>Inspire:</b> Give your hero\n+2 Attack this...   4.0
# AT_039e                                            +2 Attack this turn.   NaN
# AT_040                <b>Battlecry:</b> Give a friendly Beast +3 Hea...   4.0
# AT_040                <b>Battlecry:</b> Give a friendly Beast +3 Hea...   4.0
# AT_040                <b>Battlecry:</b> Give a friendly Beast +3 Hea...   4.0
# AT_040                <b>Battlecry:</b> Give a friendly Beast +3 Hea...   4.0
# AT_042                <b>Choose One -</b> Transform to gain <b>Charg...   2.0
# AT_042t                                                   <b>Charge</b>   2.0
# AT_042t2                                                 <b>Stealth</b>   2.0
# ...                                                                 ...   ...
# TB_SPT_DPromoSecret3  <b>Secret:</b> When your opponent summons a Le...   2.0
# TB_SPT_DPromoSecret4  <b>Secret:</b> When your opponent takes lethal...   2.0
# TB_SPT_DPromoSecret5  <b>Secret:</b> When your opponent summons a mi...   2.0
# TB_SPT_DPromoSecret6  <b>Secret:</b> When your opponent summons a mi...   2.0
# TB_SPT_DPromoSecret7  <b>Secret:</b> When your opponent summons a mi...   2.0
# TB_SPT_DPromoSecret9  <b>Secret:</b> When your opponent's hand has 9...   2.0
# TB_SPT_DPromo_Hero2                                                None   NaN
# TB_SPT_DpromoPortal   At the start of next turn, your hero is transf...   4.0
# TB_SPT_DpromoPortal   At the start of next turn, your hero is transf...   4.0
# TB_SPT_Minion1        <b>Taunt</b>\n<b>Battlecry:</b> Gain Health eq...   2.0
# TB_SPT_Minion2                         Adjacent minions have +2 Attack.   2.0
# TB_SPT_Minion2                         Adjacent minions have +2 Attack.   2.0
# TU4c_003                                   Is something in this barrel?   0.0
# TU4c_008e                           King Mukla has +8 Attack this turn.   NaN
# TU4f_007                               <b>Battlecry:</b> Throw Bananas.   1.0
# XXX_001                                                 Deal $1 damage.   0.0
# XXX_002                                                 Deal $5 damage.   0.0
# XXX_008                                      <b>Freeze</b> a character.   0.0
# XXX_020                             Set the Health of a character to 1.   0.0
# XXX_060                             Set the Health of a character to 0.   0.0
# XXX_100               <b>Battlecry:</b> Cast each spell you've cast ...   0.0
# XXX_101               Set a character's health to full, and removes ...   0.0
# XXX_102               Adds 1 health to a damaged character. Does NOT...   0.0
# XXX_103               Adds 2 health to a damaged character. Does NOT...   0.0
# XXX_104               Adds 4 health to a damaged character. Does NOT...   0.0
# XXX_105               Adds 8 health to a damaged character. Does NOT...   0.0
# XXX_107               Set a character's health to 1, and remove all ...   0.0
# XXX_110               <b>Battlecry:</b> Cast 30 random spells <i>(ta...   0.0
# hexfrog                                                    <b>Taunt</b>   0.0
# tt_010                <b>Secret:</b> When an enemy casts a spell on ...   3.0
#
#                       attack  health     rarity  collectible  \
# card_id
# AT_002                   NaN     NaN       RARE          1.0
# AT_005t                  4.0     2.0       None          NaN
# AT_006                   3.0     5.0     COMMON          1.0
# AT_007                   3.0     4.0     COMMON          1.0
# AT_009                   7.0     7.0  LEGENDARY          1.0
# AT_010                   3.0     3.0       RARE          1.0
# AT_011e                  NaN     NaN       None          NaN
# AT_012                   5.0     4.0       RARE          1.0
# AT_017                   2.0     6.0       EPIC          1.0
# AT_018                   5.0     4.0  LEGENDARY          1.0
# AT_019                   1.0     1.0       EPIC          1.0
# AT_022                   NaN     NaN       RARE          1.0
# AT_023                   5.0     4.0       RARE          1.0
# AT_028                   3.0     7.0     COMMON          1.0
# AT_030                   3.0     2.0     COMMON          1.0
# AT_032                   4.0     3.0       RARE          1.0
# AT_035t                  NaN     NaN       None          NaN
# AT_036                   8.0     4.0  LEGENDARY          1.0
# AT_037                   NaN     NaN     COMMON          1.0
# AT_038                   2.0     3.0       RARE          1.0
# AT_038                   2.0     3.0       RARE          1.0
# AT_039                   5.0     4.0       RARE          1.0
# AT_039e                  NaN     NaN       None          NaN
# AT_040                   4.0     4.0     COMMON          1.0
# AT_040                   4.0     4.0     COMMON          1.0
# AT_040                   4.0     4.0     COMMON          1.0
# AT_040                   4.0     4.0     COMMON          1.0
# AT_042                   2.0     1.0     COMMON          1.0
# AT_042t                  2.0     1.0     COMMON          NaN
# AT_042t2                 3.0     2.0     COMMON          NaN
# ...                      ...     ...        ...          ...
# TB_SPT_DPromoSecret3     NaN     NaN       None          NaN
# TB_SPT_DPromoSecret4     NaN     NaN       None          NaN
# TB_SPT_DPromoSecret5     NaN     NaN       None          NaN
# TB_SPT_DPromoSecret6     NaN     NaN       None          NaN
# TB_SPT_DPromoSecret7     NaN     NaN       None          NaN
# TB_SPT_DPromoSecret9     NaN     NaN       None          NaN
# TB_SPT_DPromo_Hero2      NaN    30.0       None          NaN
# TB_SPT_DpromoPortal      0.0    10.0       None          NaN
# TB_SPT_DpromoPortal      0.0    10.0       None          NaN
# TB_SPT_Minion1           0.0     1.0       None          NaN
# TB_SPT_Minion2           0.0     2.0       None          NaN
# TB_SPT_Minion2           0.0     2.0       None          NaN
# TU4c_003                 0.0     2.0     COMMON          NaN
# TU4c_008e                NaN     NaN       None          NaN
# TU4f_007                 1.0     2.0     COMMON          NaN
# XXX_001                  NaN     NaN     COMMON          NaN
# XXX_002                  NaN     NaN     COMMON          NaN
# XXX_008                  NaN     NaN     COMMON          NaN
# XXX_020                  NaN     NaN     COMMON          NaN
# XXX_060                  NaN     NaN       None          NaN
# XXX_100                  7.0     5.0  LEGENDARY          NaN
# XXX_101                  NaN     NaN     COMMON          NaN
# XXX_102                  NaN     NaN     COMMON          NaN
# XXX_103                  NaN     NaN     COMMON          NaN
# XXX_104                  NaN     NaN     COMMON          NaN
# XXX_105                  NaN     NaN     COMMON          NaN
# XXX_107                  NaN     NaN     COMMON          NaN
# XXX_110                  7.0     5.0  LEGENDARY          NaN
# hexfrog                  0.0     1.0     COMMON          NaN
# tt_010                   NaN     NaN       EPIC          1.0
#
#                                                                  flavor  \
# card_id
# AT_002                                               Burning man, brah.
# AT_005t                                                            None
# AT_006                 Is he aspiring or inspiring?  Make up your mind!
# AT_007                Does he sling spells, or do his spells linger ...
# AT_009                                           A masterless shamurai.
# AT_010                   Not getting trampled is really the trick here.
# AT_011e                                                            None
# AT_012                What did you expect to happen?  He's a Spawn. ...
# AT_017                A result of magical experiments carried out by...
# AT_018                She sees into your past and makes you face you...
# AT_019                Crescendo himself summoned this steed, riding ...
# AT_022                                   * Not actually Jaraxxus' fist.
# AT_023                                    We like to call him "Wesley".
# AT_028                He needed a break after that business in the V...
# AT_030                Almost went to play for Stormwind before signi...
# AT_032                I have great deal for you... for 4 damage to y...
# AT_035t                                                            None
# AT_036                Was actually a pretty nice guy before, you kno...
# AT_037                2 out of 2 saplings recommend that you summon ...
# AT_038                She loves mana crystals, she hates mana crysta...
# AT_038                She loves mana crystals, she hates mana crysta...
# AT_039                Maybe if you whistle a tune it will soothe him...
# AT_039e                                                            None
# AT_040                She was born to be something.  She is just not...
# AT_040                She was born to be something.  She is just not...
# AT_040                She was born to be something.  She is just not...
# AT_040                She was born to be something.  She is just not...
# AT_042                That's saberTEETH, not like curved pirate blad...
# AT_042t                                                            None
# AT_042t2                                                           None
# ...                                                                 ...
# TB_SPT_DPromoSecret3                                               None
# TB_SPT_DPromoSecret4                                               None
# TB_SPT_DPromoSecret5                                               None
# TB_SPT_DPromoSecret6                                               None
# TB_SPT_DPromoSecret7                                               None
# TB_SPT_DPromoSecret9                                               None
# TB_SPT_DPromo_Hero2                                                None
# TB_SPT_DpromoPortal                                                None
# TB_SPT_DpromoPortal                                                None
# TB_SPT_Minion1                                                     None
# TB_SPT_Minion2                                                     None
# TB_SPT_Minion2                                                     None
# TU4c_003                                                           None
# TU4c_008e                                                          None
# TU4f_007                                                           None
# XXX_001                                                            None
# XXX_002                                                            None
# XXX_008                                                            None
# XXX_020                                                            None
# XXX_060                                                            None
# XXX_100                                                            None
# XXX_101                                                            None
# XXX_102                                                            None
# XXX_103                                                            None
# XXX_104                                                            None
# XXX_105                                                            None
# XXX_107                                                            None
# XXX_110                                                            None
# hexfrog                                                            None
# tt_010                While it's fun to intercept enemy lightning bo...
#
#                         race how_to_earn how_to_earn_golden  \
# card_id
# AT_002                  None        None               None
# AT_005t                BEAST        None               None
# AT_006                  None        None               None
# AT_007                  None        None               None
# AT_009                  None        None               None
# AT_010                  None        None               None
# AT_011e                 None        None               None
# AT_012                  None        None               None
# AT_017                DRAGON        None               None
# AT_018                  None        None               None
# AT_019                 DEMON        None               None
# AT_022                  None        None               None
# AT_023                 DEMON        None               None
# AT_028                  None        None               None
# AT_030                  None        None               None
# AT_032                  None        None               None
# AT_035t                 None        None               None
# AT_036                  None        None               None
# AT_037                  None        None               None
# AT_038                  None        None               None
# AT_038                  None        None               None
# AT_039                 BEAST        None               None
# AT_039e                 None        None               None
# AT_040                  None        None               None
# AT_040                  None        None               None
# AT_040                  None        None               None
# AT_040                  None        None               None
# AT_042                  None        None               None
# AT_042t                BEAST        None               None
# AT_042t2               BEAST        None               None
# ...                      ...         ...                ...
# TB_SPT_DPromoSecret3    None        None               None
# TB_SPT_DPromoSecret4    None        None               None
# TB_SPT_DPromoSecret5    None        None               None
# TB_SPT_DPromoSecret6    None        None               None
# TB_SPT_DPromoSecret7    None        None               None
# TB_SPT_DPromoSecret9    None        None               None
# TB_SPT_DPromo_Hero2     None        None               None
# TB_SPT_DpromoPortal     None        None               None
# TB_SPT_DpromoPortal     None        None               None
# TB_SPT_Minion1          None        None               None
# TB_SPT_Minion2          None        None               None
# TB_SPT_Minion2          None        None               None
# TU4c_003                None        None               None
# TU4c_008e               None        None               None
# TU4f_007                None        None               None
# XXX_001                 None        None               None
# XXX_002                 None        None               None
# XXX_008                 None        None               None
# XXX_020                 None        None               None
# XXX_060                 None        None               None
# XXX_100                 None        None               None
# XXX_101                 None        None               None
# XXX_102                 None        None               None
# XXX_103                 None        None               None
# XXX_104                 None        None               None
# XXX_105                 None        None               None
# XXX_107                 None        None               None
# XXX_110                 None        None               None
# hexfrog                BEAST        None               None
# tt_010                  None        None               None
#
#                      targeting_arrow_text faction  durability  \
# card_id
# AT_002                               None    None         NaN
# AT_005t                              None    None         NaN
# AT_006                               None    None         NaN
# AT_007                               None    None         NaN
# AT_009                               None    None         NaN
# AT_010                               None    None         NaN
# AT_011e                              None    None         NaN
# AT_012                               None    None         NaN
# AT_017                               None    None         NaN
# AT_018                               None    None         NaN
# AT_019                               None    None         NaN
# AT_022                               None    None         NaN
# AT_023                               None    None         NaN
# AT_028                               None    None         NaN
# AT_030                     Deal 1 damage.    None         NaN
# AT_032                               None    None         NaN
# AT_035t                              None    None         NaN
# AT_036                               None    None         NaN
# AT_037                               None    None         NaN
# AT_038                               None    None         NaN
# AT_038                               None    None         NaN
# AT_039                               None    None         NaN
# AT_039e                              None    None         NaN
# AT_040                               None    None         NaN
# AT_040                               None    None         NaN
# AT_040                               None    None         NaN
# AT_040                               None    None         NaN
# AT_042                               None    None         NaN
# AT_042t                              None    None         NaN
# AT_042t2                             None    None         NaN
# ...                                   ...     ...         ...
# TB_SPT_DPromoSecret3                 None    None         NaN
# TB_SPT_DPromoSecret4                 None    None         NaN
# TB_SPT_DPromoSecret5                 None    None         NaN
# TB_SPT_DPromoSecret6                 None    None         NaN
# TB_SPT_DPromoSecret7                 None    None         NaN
# TB_SPT_DPromoSecret9                 None    None         NaN
# TB_SPT_DPromo_Hero2                  None    None         NaN
# TB_SPT_DpromoPortal                  None    None         NaN
# TB_SPT_DpromoPortal                  None    None         NaN
# TB_SPT_Minion1                       None    None         NaN
# TB_SPT_Minion2                       None    None         NaN
# TB_SPT_Minion2                       None    None         NaN
# TU4c_003                             None    None         NaN
# TU4c_008e                            None    None         NaN
# TU4f_007                             None    None         NaN
# XXX_001                              None    None         NaN
# XXX_002                              None    None         NaN
# XXX_008                              None    None         NaN
# XXX_020                              None    None         NaN
# XXX_060                              None    None         NaN
# XXX_100                              None    None         NaN
# XXX_101                              None    None         NaN
# XXX_102                              None    None         NaN
# XXX_103                              None    None         NaN
# XXX_104                              None    None         NaN
# XXX_105                              None    None         NaN
# XXX_107                              None    None         NaN
# XXX_110                              None    None         NaN
# hexfrog                              None    None         NaN
# tt_010                               None    None         NaN
#
#                                   mechanic         play_requirement  value
# card_id
# AT_002                              SECRET                      NaN    NaN
# AT_005t                             CHARGE                      NaN    NaN
# AT_006                             INSPIRE                      NaN    NaN
# AT_007                           BATTLECRY                      NaN    NaN
# AT_009                         DEATHRATTLE                      NaN    NaN
# AT_010                           BATTLECRY                      NaN    NaN
# AT_011e                               AURA                      NaN    NaN
# AT_012                             INSPIRE                      NaN    NaN
# AT_017                           BATTLECRY                      NaN    NaN
# AT_018                             INSPIRE                      NaN    NaN
# AT_019                         DEATHRATTLE                      NaN    NaN
# AT_022                InvisibleDeathrattle                      NaN    NaN
# AT_023                             INSPIRE                      NaN    NaN
# AT_028                               COMBO                      NaN    NaN
# AT_030                               COMBO     REQ_TARGET_FOR_COMBO    0.0
# AT_032                           BATTLECRY                      NaN    NaN
# AT_035t                            TOPDECK                      NaN    NaN
# AT_036                         DEATHRATTLE                      NaN    NaN
# AT_037                          CHOOSE_ONE       REQ_TARGET_TO_PLAY    0.0
# AT_038                           BATTLECRY                      NaN    NaN
# AT_038                         DEATHRATTLE                      NaN    NaN
# AT_039                             INSPIRE                      NaN    NaN
# AT_039e                TAG_ONE_TURN_EFFECT                      NaN    NaN
# AT_040                           BATTLECRY      REQ_FRIENDLY_TARGET    0.0
# AT_040                           BATTLECRY  REQ_TARGET_IF_AVAILABLE    0.0
# AT_040                           BATTLECRY     REQ_TARGET_WITH_RACE   20.0
# AT_040                           BATTLECRY        REQ_MINION_TARGET    0.0
# AT_042                          CHOOSE_ONE                      NaN    NaN
# AT_042t                             CHARGE                      NaN    NaN
# AT_042t2                           STEALTH                      NaN    NaN
# ...                                    ...                      ...    ...
# TB_SPT_DPromoSecret3                SECRET                      NaN    NaN
# TB_SPT_DPromoSecret4                SECRET                      NaN    NaN
# TB_SPT_DPromoSecret5                SECRET                      NaN    NaN
# TB_SPT_DPromoSecret6                SECRET                      NaN    NaN
# TB_SPT_DPromoSecret7                SECRET                      NaN    NaN
# TB_SPT_DPromoSecret9                SECRET                      NaN    NaN
# TB_SPT_DPromo_Hero2   InvisibleDeathrattle                      NaN    NaN
# TB_SPT_DpromoPortal              BATTLECRY                      NaN    NaN
# TB_SPT_DpromoPortal                 IMMUNE                      NaN    NaN
# TB_SPT_Minion1                       TAUNT                      NaN    NaN
# TB_SPT_Minion2               ADJACENT_BUFF                      NaN    NaN
# TB_SPT_Minion2                        AURA                      NaN    NaN
# TU4c_003                       DEATHRATTLE                      NaN    NaN
# TU4c_008e              TAG_ONE_TURN_EFFECT                      NaN    NaN
# TU4f_007                         BATTLECRY                      NaN    NaN
# XXX_001                 ImmuneToSpellpower       REQ_TARGET_TO_PLAY    0.0
# XXX_002                 ImmuneToSpellpower       REQ_TARGET_TO_PLAY    0.0
# XXX_008                             FREEZE       REQ_TARGET_TO_PLAY    0.0
# XXX_020                 ImmuneToSpellpower       REQ_TARGET_TO_PLAY    0.0
# XXX_060                 ImmuneToSpellpower       REQ_TARGET_TO_PLAY    0.0
# XXX_100                          BATTLECRY                      NaN    NaN
# XXX_101                 ImmuneToSpellpower       REQ_TARGET_TO_PLAY    0.0
# XXX_102                 ImmuneToSpellpower       REQ_TARGET_TO_PLAY    0.0
# XXX_103                 ImmuneToSpellpower       REQ_TARGET_TO_PLAY    0.0
# XXX_104                 ImmuneToSpellpower       REQ_TARGET_TO_PLAY    0.0
# XXX_105                 ImmuneToSpellpower       REQ_TARGET_TO_PLAY    0.0
# XXX_107                 ImmuneToSpellpower       REQ_TARGET_TO_PLAY    0.0
# XXX_110                          BATTLECRY                      NaN    NaN
# hexfrog                              TAUNT                      NaN    NaN
# tt_010                              SECRET                      NaN    NaN
#
# [1226 rows x 20 columns]

# %% [markdown]
# Note that the results of this sort of join are dependent upon the position of each table--if we were to make `cards_with_mechanics_df` the right table and `play_requirements_df` the left table and then perform a **_Right Join_**, our results would be the same.
#
# **_Question:_**
#
# Describe what was included from each table in this join.
#
# Write your answer below this line:
#
# This table is our list of cards with mechanics, with the info of play requirements added in to each series in the cards with mechanics table
# ________________________________________________________________________________
#
#
#
# #### Outer Joins
#
# In the cell below, perform an outer join between `cards_df` and `dust_df`. Since these tables contain columns with the same name, we'll need to specify a suffix for at least one of them, so that the column can be renamed to avoid a naming collision.
#
# During this join, set the `rsuffix` parameter to `_dust`

# %%
outer_join_df = cards_df.join(dust_df, how='outer', rsuffix='_dust')
outer_join_df
# Out:
#                player_class         type  \
# card_id
# AT_001                 MAGE        SPELL
# AT_001                 MAGE        SPELL
# AT_001                 MAGE        SPELL
# AT_001                 MAGE        SPELL
# AT_002                 MAGE        SPELL
# AT_002                 MAGE        SPELL
# AT_002                 MAGE        SPELL
# AT_002                 MAGE        SPELL
# AT_003                 MAGE       MINION
# AT_003                 MAGE       MINION
# AT_003                 MAGE       MINION
# AT_003                 MAGE       MINION
# AT_004                 MAGE        SPELL
# AT_004                 MAGE        SPELL
# AT_004                 MAGE        SPELL
# AT_004                 MAGE        SPELL
# AT_005                 MAGE        SPELL
# AT_005                 MAGE        SPELL
# AT_005                 MAGE        SPELL
# AT_005                 MAGE        SPELL
# AT_005t             NEUTRAL       MINION
# AT_006                 MAGE       MINION
# AT_006                 MAGE       MINION
# AT_006                 MAGE       MINION
# AT_006                 MAGE       MINION
# AT_006e                MAGE  ENCHANTMENT
# AT_007                 MAGE       MINION
# AT_007                 MAGE       MINION
# AT_007                 MAGE       MINION
# AT_007                 MAGE       MINION
# ...                     ...          ...
# XXX_110             NEUTRAL       MINION
# XXX_111             NEUTRAL        SPELL
# XXX_111e            NEUTRAL  ENCHANTMENT
# XXX_112             NEUTRAL        SPELL
# XXX_113             NEUTRAL        SPELL
# XXX_115             NEUTRAL        SPELL
# XXX_115e            NEUTRAL  ENCHANTMENT
# XXX_119             NEUTRAL        SPELL
# XXX_119e               None  ENCHANTMENT
# XXX_999_Crash       NEUTRAL        SPELL
# ds1_whelptoken      NEUTRAL       MINION
# hexfrog             NEUTRAL       MINION
# skele11             NEUTRAL       MINION
# skele21             NEUTRAL       MINION
# skele21             NEUTRAL       MINION
# skele21             NEUTRAL       MINION
# skele21             NEUTRAL       MINION
# tt_004              NEUTRAL       MINION
# tt_004              NEUTRAL       MINION
# tt_004              NEUTRAL       MINION
# tt_004              NEUTRAL       MINION
# tt_004o             NEUTRAL  ENCHANTMENT
# tt_010                 MAGE        SPELL
# tt_010                 MAGE        SPELL
# tt_010                 MAGE        SPELL
# tt_010                 MAGE        SPELL
# tt_010a                MAGE       MINION
# tt_010a                MAGE       MINION
# tt_010a                MAGE       MINION
# tt_010a                MAGE       MINION
#
#                                                   name      set  \
# card_id
# AT_001                                     Flame Lance      TGT
# AT_001                                     Flame Lance      TGT
# AT_001                                     Flame Lance      TGT
# AT_001                                     Flame Lance      TGT
# AT_002                                          Effigy      TGT
# AT_002                                          Effigy      TGT
# AT_002                                          Effigy      TGT
# AT_002                                          Effigy      TGT
# AT_003                                     Fallen Hero      TGT
# AT_003                                     Fallen Hero      TGT
# AT_003                                     Fallen Hero      TGT
# AT_003                                     Fallen Hero      TGT
# AT_004                                    Arcane Blast      TGT
# AT_004                                    Arcane Blast      TGT
# AT_004                                    Arcane Blast      TGT
# AT_004                                    Arcane Blast      TGT
# AT_005                                 Polymorph: Boar      TGT
# AT_005                                 Polymorph: Boar      TGT
# AT_005                                 Polymorph: Boar      TGT
# AT_005                                 Polymorph: Boar      TGT
# AT_005t                                           Boar      TGT
# AT_006                                Dalaran Aspirant      TGT
# AT_006                                Dalaran Aspirant      TGT
# AT_006                                Dalaran Aspirant      TGT
# AT_006                                Dalaran Aspirant      TGT
# AT_006e                               Power of Dalaran      TGT
# AT_007                                    Spellslinger      TGT
# AT_007                                    Spellslinger      TGT
# AT_007                                    Spellslinger      TGT
# AT_007                                    Spellslinger      TGT
# ...                                                ...      ...
# XXX_110                         Yogg-Saron Test (Auto)    CHEAT
# XXX_111           AI Buddy - All Charge, All Windfury!    CHEAT
# XXX_111e        All Charge, All Windfury, All The Time    CHEAT
# XXX_112                                      Fill Deck    CHEAT
# XXX_113                                          Again    CHEAT
# XXX_115                           Destroy Played Cards    CHEAT
# XXX_115e               Destroy Played Card Enchantment    CHEAT
# XXX_119                                Death No Rattle    CHEAT
# XXX_119e                               Death No Rattle    CHEAT
# XXX_999_Crash                         Crash the server    CHEAT
# ds1_whelptoken                                   Whelp  EXPERT1
# hexfrog                                           Frog     CORE
# skele11                                       Skeleton     CORE
# skele21                                  Damaged Golem  EXPERT1
# skele21                                  Damaged Golem  EXPERT1
# skele21                                  Damaged Golem  EXPERT1
# skele21                                  Damaged Golem  EXPERT1
# tt_004                               Flesheating Ghoul  EXPERT1
# tt_004                               Flesheating Ghoul  EXPERT1
# tt_004                               Flesheating Ghoul  EXPERT1
# tt_004                               Flesheating Ghoul  EXPERT1
# tt_004o                                    Cannibalize  EXPERT1
# tt_010                                     Spellbender  EXPERT1
# tt_010                                     Spellbender  EXPERT1
# tt_010                                     Spellbender  EXPERT1
# tt_010                                     Spellbender  EXPERT1
# tt_010a                                    Spellbender  EXPERT1
# tt_010a                                    Spellbender  EXPERT1
# tt_010a                                    Spellbender  EXPERT1
# tt_010a                                    Spellbender  EXPERT1
#
#                                                              text  cost  \
# card_id
# AT_001                                Deal $8 damage to a minion.   5.0
# AT_001                                Deal $8 damage to a minion.   5.0
# AT_001                                Deal $8 damage to a minion.   5.0
# AT_001                                Deal $8 damage to a minion.   5.0
# AT_002          <b>Secret:</b> When a friendly minion dies, su...   3.0
# AT_002          <b>Secret:</b> When a friendly minion dies, su...   3.0
# AT_002          <b>Secret:</b> When a friendly minion dies, su...   3.0
# AT_002          <b>Secret:</b> When a friendly minion dies, su...   3.0
# AT_003                      Your Hero Power deals 1 extra damage.   2.0
# AT_003                      Your Hero Power deals 1 extra damage.   2.0
# AT_003                      Your Hero Power deals 1 extra damage.   2.0
# AT_003                      Your Hero Power deals 1 extra damage.   2.0
# AT_004          Deal $2 damage to a minion. This spell gets do...   1.0
# AT_004          Deal $2 damage to a minion. This spell gets do...   1.0
# AT_004          Deal $2 damage to a minion. This spell gets do...   1.0
# AT_004          Deal $2 damage to a minion. This spell gets do...   1.0
# AT_005          Transform a minion into a 4/2 Boar with <b>Cha...   3.0
# AT_005          Transform a minion into a 4/2 Boar with <b>Cha...   3.0
# AT_005          Transform a minion into a 4/2 Boar with <b>Cha...   3.0
# AT_005          Transform a minion into a 4/2 Boar with <b>Cha...   3.0
# AT_005t                                             <b>Charge</b>   3.0
# AT_006               <b>Inspire:</b> Gain <b>Spell Damage +1</b>.   4.0
# AT_006               <b>Inspire:</b> Gain <b>Spell Damage +1</b>.   4.0
# AT_006               <b>Inspire:</b> Gain <b>Spell Damage +1</b>.   4.0
# AT_006               <b>Inspire:</b> Gain <b>Spell Damage +1</b>.   4.0
# AT_006e                                   Increased Spell Damage.   NaN
# AT_007          <b>Battlecry:</b> Add a random spell to each p...   3.0
# AT_007          <b>Battlecry:</b> Add a random spell to each p...   3.0
# AT_007          <b>Battlecry:</b> Add a random spell to each p...   3.0
# AT_007          <b>Battlecry:</b> Add a random spell to each p...   3.0
# ...                                                           ...   ...
# XXX_110         <b>Battlecry:</b> Cast 30 random spells <i>(ta...   0.0
# XXX_111         Play this card to give all minions <b>Charge</...   0.0
# XXX_111e        Your minions always have <b>Charge</b> and <b>...   NaN
# XXX_112                Fill target hero's deck with random cards.   0.0
# XXX_113                                                      None   0.0
# XXX_115           Whenever a player summons a minion, destroy it.   0.0
# XXX_115e          Whenever a player summons a minion, destroy it.   NaN
# XXX_119         Died without triggering <b>Deathrattle</b>, Al...   0.0
# XXX_119e        Died without triggering <b>Deathrattle</b>, Al...   NaN
# XXX_999_Crash                                    Crash the server   0.0
# ds1_whelptoken                                               None   1.0
# hexfrog                                              <b>Taunt</b>   0.0
# skele11                                                   <b></b>   1.0
# skele21                                                      None   1.0
# skele21                                                      None   1.0
# skele21                                                      None   1.0
# skele21                                                      None   1.0
# tt_004                    Whenever a minion dies, gain +1 Attack.   3.0
# tt_004                    Whenever a minion dies, gain +1 Attack.   3.0
# tt_004                    Whenever a minion dies, gain +1 Attack.   3.0
# tt_004                    Whenever a minion dies, gain +1 Attack.   3.0
# tt_004o                                         Increased Attack.   NaN
# tt_010          <b>Secret:</b> When an enemy casts a spell on ...   3.0
# tt_010          <b>Secret:</b> When an enemy casts a spell on ...   3.0
# tt_010          <b>Secret:</b> When an enemy casts a spell on ...   3.0
# tt_010          <b>Secret:</b> When an enemy casts a spell on ...   3.0
# tt_010a                                                      None   1.0
# tt_010a                                                      None   1.0
# tt_010a                                                      None   1.0
# tt_010a                                                      None   1.0
#
#                 attack  health     rarity  collectible  \
# card_id
# AT_001             NaN     NaN     COMMON          1.0
# AT_001             NaN     NaN     COMMON          1.0
# AT_001             NaN     NaN     COMMON          1.0
# AT_001             NaN     NaN     COMMON          1.0
# AT_002             NaN     NaN       RARE          1.0
# AT_002             NaN     NaN       RARE          1.0
# AT_002             NaN     NaN       RARE          1.0
# AT_002             NaN     NaN       RARE          1.0
# AT_003             3.0     2.0       RARE          1.0
# AT_003             3.0     2.0       RARE          1.0
# AT_003             3.0     2.0       RARE          1.0
# AT_003             3.0     2.0       RARE          1.0
# AT_004             NaN     NaN       EPIC          1.0
# AT_004             NaN     NaN       EPIC          1.0
# AT_004             NaN     NaN       EPIC          1.0
# AT_004             NaN     NaN       EPIC          1.0
# AT_005             NaN     NaN       RARE          1.0
# AT_005             NaN     NaN       RARE          1.0
# AT_005             NaN     NaN       RARE          1.0
# AT_005             NaN     NaN       RARE          1.0
# AT_005t            4.0     2.0       None          NaN
# AT_006             3.0     5.0     COMMON          1.0
# AT_006             3.0     5.0     COMMON          1.0
# AT_006             3.0     5.0     COMMON          1.0
# AT_006             3.0     5.0     COMMON          1.0
# AT_006e            NaN     NaN       None          NaN
# AT_007             3.0     4.0     COMMON          1.0
# AT_007             3.0     4.0     COMMON          1.0
# AT_007             3.0     4.0     COMMON          1.0
# AT_007             3.0     4.0     COMMON          1.0
# ...                ...     ...        ...          ...
# XXX_110            7.0     5.0  LEGENDARY          NaN
# XXX_111            NaN     NaN     COMMON          NaN
# XXX_111e           NaN     NaN       None          NaN
# XXX_112            NaN     NaN     COMMON          NaN
# XXX_113            NaN     NaN     COMMON          NaN
# XXX_115            NaN     NaN     COMMON          NaN
# XXX_115e           NaN     NaN     COMMON          NaN
# XXX_119            NaN     NaN       None          NaN
# XXX_119e           NaN     NaN       None          NaN
# XXX_999_Crash      NaN     NaN     COMMON          NaN
# ds1_whelptoken     1.0     1.0       None          NaN
# hexfrog            0.0     1.0     COMMON          NaN
# skele11            1.0     1.0     COMMON          NaN
# skele21            2.0     1.0     COMMON          NaN
# skele21            2.0     1.0     COMMON          NaN
# skele21            2.0     1.0     COMMON          NaN
# skele21            2.0     1.0     COMMON          NaN
# tt_004             2.0     3.0     COMMON          1.0
# tt_004             2.0     3.0     COMMON          1.0
# tt_004             2.0     3.0     COMMON          1.0
# tt_004             2.0     3.0     COMMON          1.0
# tt_004o            NaN     NaN       None          NaN
# tt_010             NaN     NaN       EPIC          1.0
# tt_010             NaN     NaN       EPIC          1.0
# tt_010             NaN     NaN       EPIC          1.0
# tt_010             NaN     NaN       EPIC          1.0
# tt_010a            1.0     3.0       EPIC          NaN
# tt_010a            1.0     3.0       EPIC          NaN
# tt_010a            1.0     3.0       EPIC          NaN
# tt_010a            1.0     3.0       EPIC          NaN
#
#                                                            flavor        race  \
# card_id
# AT_001          It's on the rack next to ice lance, acid lance...        None
# AT_001          It's on the rack next to ice lance, acid lance...        None
# AT_001          It's on the rack next to ice lance, acid lance...        None
# AT_001          It's on the rack next to ice lance, acid lance...        None
# AT_002                                         Burning man, brah.        None
# AT_002                                         Burning man, brah.        None
# AT_002                                         Burning man, brah.        None
# AT_002                                         Burning man, brah.        None
# AT_003                                       And he can't get up.        None
# AT_003                                       And he can't get up.        None
# AT_003                                       And he can't get up.        None
# AT_003                                       And he can't get up.        None
# AT_004                                  Now with 100% more blast!        None
# AT_004                                  Now with 100% more blast!        None
# AT_004                                  Now with 100% more blast!        None
# AT_004                                  Now with 100% more blast!        None
# AT_005                                        It's always Huffer.        None
# AT_005                                        It's always Huffer.        None
# AT_005                                        It's always Huffer.        None
# AT_005                                        It's always Huffer.        None
# AT_005t                                                      None       BEAST
# AT_006           Is he aspiring or inspiring?  Make up your mind!        None
# AT_006           Is he aspiring or inspiring?  Make up your mind!        None
# AT_006           Is he aspiring or inspiring?  Make up your mind!        None
# AT_006           Is he aspiring or inspiring?  Make up your mind!        None
# AT_006e                                                      None        None
# AT_007          Does he sling spells, or do his spells linger ...        None
# AT_007          Does he sling spells, or do his spells linger ...        None
# AT_007          Does he sling spells, or do his spells linger ...        None
# AT_007          Does he sling spells, or do his spells linger ...        None
# ...                                                           ...         ...
# XXX_110                                                      None        None
# XXX_111                                                      None        None
# XXX_111e                                                     None        None
# XXX_112                                                      None        None
# XXX_113                                                      None        None
# XXX_115                                                      None        None
# XXX_115e                                                     None        None
# XXX_119                                                      None        None
# XXX_119e                                                     None        None
# XXX_999_Crash                                                None        None
# ds1_whelptoken                                               None      DRAGON
# hexfrog                                                      None       BEAST
# skele11                                                      None        None
# skele21                                                      None  MECHANICAL
# skele21                                                      None  MECHANICAL
# skele21                                                      None  MECHANICAL
# skele21                                                      None  MECHANICAL
# tt_004          'Flesheating' is an unfair name.  It's just th...        None
# tt_004          'Flesheating' is an unfair name.  It's just th...        None
# tt_004          'Flesheating' is an unfair name.  It's just th...        None
# tt_004          'Flesheating' is an unfair name.  It's just th...        None
# tt_004o                                                      None        None
# tt_010          While it's fun to intercept enemy lightning bo...        None
# tt_010          While it's fun to intercept enemy lightning bo...        None
# tt_010          While it's fun to intercept enemy lightning bo...        None
# tt_010          While it's fun to intercept enemy lightning bo...        None
# tt_010a                                                      None        None
# tt_010a                                                      None        None
# tt_010a                                                      None        None
# tt_010a                                                      None        None
#
#                how_to_earn how_to_earn_golden targeting_arrow_text faction  \
# card_id
# AT_001                None               None                 None    None
# AT_001                None               None                 None    None
# AT_001                None               None                 None    None
# AT_001                None               None                 None    None
# AT_002                None               None                 None    None
# AT_002                None               None                 None    None
# AT_002                None               None                 None    None
# AT_002                None               None                 None    None
# AT_003                None               None                 None    None
# AT_003                None               None                 None    None
# AT_003                None               None                 None    None
# AT_003                None               None                 None    None
# AT_004                None               None                 None    None
# AT_004                None               None                 None    None
# AT_004                None               None                 None    None
# AT_004                None               None                 None    None
# AT_005                None               None                 None    None
# AT_005                None               None                 None    None
# AT_005                None               None                 None    None
# AT_005                None               None                 None    None
# AT_005t               None               None                 None    None
# AT_006                None               None                 None    None
# AT_006                None               None                 None    None
# AT_006                None               None                 None    None
# AT_006                None               None                 None    None
# AT_006e               None               None                 None    None
# AT_007                None               None                 None    None
# AT_007                None               None                 None    None
# AT_007                None               None                 None    None
# AT_007                None               None                 None    None
# ...                    ...                ...                  ...     ...
# XXX_110               None               None                 None    None
# XXX_111               None               None                 None    None
# XXX_111e              None               None                 None    None
# XXX_112               None               None                 None    None
# XXX_113               None               None                 None    None
# XXX_115               None               None                 None    None
# XXX_115e              None               None                 None    None
# XXX_119               None               None                 None    None
# XXX_119e              None               None                 None    None
# XXX_999_Crash         None               None                 None    None
# ds1_whelptoken        None               None                 None    None
# hexfrog               None               None                 None    None
# skele11               None               None                 None    None
# skele21               None               None                 None    None
# skele21               None               None                 None    None
# skele21               None               None                 None    None
# skele21               None               None                 None    None
# tt_004                None               None                 None    None
# tt_004                None               None                 None    None
# tt_004                None               None                 None    None
# tt_004                None               None                 None    None
# tt_004o               None               None                 None    None
# tt_010                None               None                 None    None
# tt_010                None               None                 None    None
# tt_010                None               None                 None    None
# tt_010                None               None                 None    None
# tt_010a               None               None                 None    None
# tt_010a               None               None                 None    None
# tt_010a               None               None                 None    None
# tt_010a               None               None                 None    None
#
#                 durability             action  cost_dust
# card_id
# AT_001                 NaN    CRAFTING_NORMAL       40.0
# AT_001                 NaN    CRAFTING_GOLDEN      400.0
# AT_001                 NaN  DISENCHANT_NORMAL        5.0
# AT_001                 NaN  DISENCHANT_GOLDEN       50.0
# AT_002                 NaN    CRAFTING_NORMAL      100.0
# AT_002                 NaN    CRAFTING_GOLDEN      800.0
# AT_002                 NaN  DISENCHANT_NORMAL       20.0
# AT_002                 NaN  DISENCHANT_GOLDEN      100.0
# AT_003                 NaN    CRAFTING_NORMAL      100.0
# AT_003                 NaN    CRAFTING_GOLDEN      800.0
# AT_003                 NaN  DISENCHANT_NORMAL       20.0
# AT_003                 NaN  DISENCHANT_GOLDEN      100.0
# AT_004                 NaN    CRAFTING_NORMAL      400.0
# AT_004                 NaN    CRAFTING_GOLDEN     1600.0
# AT_004                 NaN  DISENCHANT_NORMAL      100.0
# AT_004                 NaN  DISENCHANT_GOLDEN      400.0
# AT_005                 NaN    CRAFTING_NORMAL      100.0
# AT_005                 NaN    CRAFTING_GOLDEN      800.0
# AT_005                 NaN  DISENCHANT_NORMAL       20.0
# AT_005                 NaN  DISENCHANT_GOLDEN      100.0
# AT_005t                NaN                NaN        NaN
# AT_006                 NaN    CRAFTING_NORMAL       40.0
# AT_006                 NaN    CRAFTING_GOLDEN      400.0
# AT_006                 NaN  DISENCHANT_NORMAL        5.0
# AT_006                 NaN  DISENCHANT_GOLDEN       50.0
# AT_006e                NaN                NaN        NaN
# AT_007                 NaN    CRAFTING_NORMAL       40.0
# AT_007                 NaN    CRAFTING_GOLDEN      400.0
# AT_007                 NaN  DISENCHANT_NORMAL        5.0
# AT_007                 NaN  DISENCHANT_GOLDEN       50.0
# ...                    ...                ...        ...
# XXX_110                NaN                NaN        NaN
# XXX_111                NaN                NaN        NaN
# XXX_111e               NaN                NaN        NaN
# XXX_112                NaN                NaN        NaN
# XXX_113                NaN                NaN        NaN
# XXX_115                NaN                NaN        NaN
# XXX_115e               NaN                NaN        NaN
# XXX_119                NaN                NaN        NaN
# XXX_119e               NaN                NaN        NaN
# XXX_999_Crash          NaN                NaN        NaN
# ds1_whelptoken         NaN                NaN        NaN
# hexfrog                NaN                NaN        NaN
# skele11                NaN                NaN        NaN
# skele21                NaN    CRAFTING_NORMAL       40.0
# skele21                NaN    CRAFTING_GOLDEN      400.0
# skele21                NaN  DISENCHANT_NORMAL        5.0
# skele21                NaN  DISENCHANT_GOLDEN       50.0
# tt_004                 NaN    CRAFTING_NORMAL       40.0
# tt_004                 NaN    CRAFTING_GOLDEN      400.0
# tt_004                 NaN  DISENCHANT_NORMAL        5.0
# tt_004                 NaN  DISENCHANT_GOLDEN       50.0
# tt_004o                NaN                NaN        NaN
# tt_010                 NaN    CRAFTING_NORMAL      400.0
# tt_010                 NaN    CRAFTING_GOLDEN     1600.0
# tt_010                 NaN  DISENCHANT_NORMAL      100.0
# tt_010                 NaN  DISENCHANT_GOLDEN      400.0
# tt_010a                NaN    CRAFTING_NORMAL      400.0
# tt_010a                NaN    CRAFTING_GOLDEN     1600.0
# tt_010a                NaN  DISENCHANT_NORMAL      100.0
# tt_010a                NaN  DISENCHANT_GOLDEN      400.0
#
# [5849 rows x 19 columns]

# %% [markdown]
# Inspect the output above.  Note that the naming collision has been avoided by renaming the `cost` column from the right table to `cost_dust`.
#
# ## Summary
#
# In this lab, we learned how to:
#
# * Concatenate multiple DataFrames together into a single DataFrame
# * Use `sqlalchemy` to connect to a sqlite database and read in individual tables as DataFrames
# * Understand and execute the various types of joins (inner, outer, left, and right joins)
